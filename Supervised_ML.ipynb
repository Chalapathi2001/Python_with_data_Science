# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# %%
import pandas as pd
df=pd.read_csv('C:/Users/Chalapathi/Downloads/archive (1)/daily.csv')
df
# Out:
#          date  states    positive    negative  pending  hospitalizedCurrently  \
# 0    20210307      56  28756489.0  74582825.0  11808.0                40199.0
# 1    20210306      56  28714654.0  74450990.0  11783.0                41401.0
# 2    20210305      56  28654639.0  74307155.0  12213.0                42541.0
# 3    20210304      56  28585852.0  74035238.0  12405.0                44172.0
# 4    20210303      56  28520365.0  73857281.0  11778.0                45462.0
# ..        ...     ...         ...         ...      ...                    ...
# 415  20200117       1         0.0         NaN      NaN                    NaN
# 416  20200116       1         0.0         NaN      NaN                    NaN
# 417  20200115       1         0.0         NaN      NaN                    NaN
# 418  20200114       1         0.0         NaN      NaN                    NaN
# 419  20200113       1         NaN         NaN      NaN                    NaN
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                  776361.0          8134.0          45475.0
# 1                  775635.0          8409.0          45453.0
# 2                  775132.0          8634.0          45373.0
# 3                  772351.0          8970.0          45293.0
# 4                  770821.0          9359.0          45214.0
# ..                      ...             ...              ...
# 415                     NaN             NaN              NaN
# 416                     NaN             NaN              NaN
# 417                     NaN             NaN              NaN
# 418                     NaN             NaN              NaN
# 419                     NaN             NaN              NaN
#
#      onVentilatorCurrently  ...          lastModified recovered  total  \
# 0                   2802.0  ...  2021-03-07T24:00:00Z       NaN      0
# 1                   2811.0  ...  2021-03-06T24:00:00Z       NaN      0
# 2                   2889.0  ...  2021-03-05T24:00:00Z       NaN      0
# 3                   2973.0  ...  2021-03-04T24:00:00Z       NaN      0
# 4                   3094.0  ...  2021-03-03T24:00:00Z       NaN      0
# ..                     ...  ...                   ...       ...    ...
# 415                    NaN  ...  2020-01-17T24:00:00Z       NaN      0
# 416                    NaN  ...  2020-01-16T24:00:00Z       NaN      0
# 417                    NaN  ...  2020-01-15T24:00:00Z       NaN      0
# 418                    NaN  ...  2020-01-14T24:00:00Z       NaN      0
# 419                    NaN  ...  2020-01-13T24:00:00Z       NaN      0
#
#      posNeg  deathIncrease hospitalizedIncrease  negativeIncrease  \
# 0         0            842                  726            131835
# 1         0           1680                  503            143835
# 2         0           2221                 2781            271917
# 3         0           1743                 1530            177957
# 4         0           2449                 2172            267001
# ..      ...            ...                  ...               ...
# 415       0              0                    0                 0
# 416       0              0                    0                 0
# 417       0              0                    0                 0
# 418       0              0                    0                 0
# 419       0              0                    0                 0
#
#      positiveIncrease  totalTestResultsIncrease  \
# 0               41835                   1170059
# 1               60015                   1430992
# 2               68787                   1744417
# 3               65487                   1590984
# 4               66836                   1406795
# ..                ...                       ...
# 415                 0                         0
# 416                 0                         0
# 417                 0                         0
# 418                 0                         0
# 419                 0                         0
#
#                                          hash
# 0    a80d0063822e251249fd9a44730c49cb23defd83
# 1    dae5e558c24adb86686bbd58c08cce5f610b8bb0
# 2    724844c01659d0103801c57c0f72bf8cc8ab025c
# 3    5c549ad30f9abf48dc5de36d20fa707014be1ff3
# 4    fef6c425d2b773a9221fe353f13852f3e4a4bfb0
# ..                                        ...
# 415  5fd7ed7fb0f83565ea0aaaf5ff6104e5860be2d6
# 416  4c0f2ea879eefec1a18a93bcd8a382ea56cd452d
# 417  8a449023413eea473277416e9e30ae126c6af047
# 418  fe399466a3dfbe0221a18ed5cacb39a3882d72f8
# 419  5672debf187b183735be63f6bd85834ead0047ff
#
# [420 rows x 25 columns]

# %%
df1 = df.iloc[0:31,0:4]
df1
# Out:
#         date  states    positive    negative
# 0   20210307      56  28756489.0  74582825.0
# 1   20210306      56  28714654.0  74450990.0
# 2   20210305      56  28654639.0  74307155.0
# 3   20210304      56  28585852.0  74035238.0
# 4   20210303      56  28520365.0  73857281.0
# 5   20210302      56  28453529.0  73590280.0
# 6   20210301      56  28399281.0  73334501.0
# 7   20210228      56  28351189.0  73216424.0
# 8   20210227      56  28296840.0  73012825.0
# 9   20210226      56  28225595.0  72807735.0
# 10  20210225      56  28150738.0  72530906.0
# 11  20210224      56  28075173.0  72258697.0
# 12  20210223      56  28001915.0  72013379.0
# 13  20210222      56  27932810.0  71788112.0
# 14  20210221      56  27880280.0  71664501.0
# 15  20210220      56  27821578.0  71507723.0
# 16  20210219      56  27749224.0  71365933.0
# 17  20210218      56  27674548.0  71141178.0
# 18  20210217      56  27607724.0  70922687.0
# 19  20210216      56  27540885.0  70689021.0
# 20  20210215      56  27484573.0  70587919.0
# 21  20210214      56  27429496.0  70444531.0
# 22  20210213      56  27357332.0  70272654.0
# 23  20210212      56  27266690.0  70038361.0
# 24  20210211      56  27165660.0  69782378.0
# 25  20210210      56  27063243.0  69522254.0
# 26  20210209      56  26968049.0  69366393.0
# 27  20210208      56  26875063.0  69029225.0
# 28  20210207      56  26797326.0  68887069.0
# 29  20210206      56  26701332.0  68678766.0
# 30  20210205      56  26586775.0  68396289.0

# %%
from matplotlib import pyplot as plt
X=df1["positive"]
Y=df1["negative"]
plt.scatter(X,Y,color='r',marker='X',label='data points')
plt.xlabel("positive")
plt.ylabel("negative")
plt.title('Scatter Plot')
plt.show()

# %%
#Load data
data = load_iris()
X = data.data
Y = data.target

# %%
#Split dataset into training data and testing data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=50)

# %%
#Create LogisticRegression Model
model = LogisticRegression()

# %%
#train the model on train data
model.fit(X_train,Y_train)
#make prediction on test data
y_pred=model.predict(X_test)
accuracy=accuracy_score(Y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.9666666666666667

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier

# %%
#load the Dataset
iris = load_iris()
X = iris.data
Y = iris.target

# %%
#create DecisionTreeClassifier instance
clf = DecisionTreeClassifier()

# %%
#train the classifier on the training data
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
#make prediction on the testing data
Y_pred=clf.predict(X_test)

# %%
#calculate accuracy
accuracy=accuracy_score(Y_test,Y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.6

# %%
#RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
#create RandomForestClassifier instance
clf = RandomForestClassifier(n_estimators=10, random_state=4)

# %%
#train the classifier on the training data
clf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=4)

# %%
#make prediction on the testing data
Y_pred=clf.predict(X_test)

# %%
#calculate accuracy
accuracy=accuracy_score(Y_test,Y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.55

# %%
import matplotlib.pyplot as plt
x = ["DecisionTreeClassifier","RandomForestClassifier","LogisticRegression"]
y = ["Accuracy"]
plt.bar(x,y)
plt.xlabel('X_axis Label')
plt.ylabel('Y-axis Label')
plt.title('Bar Graph')

plt.grid(True)
plt.show()
